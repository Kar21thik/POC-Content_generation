# %%
"""
1. What is MCP? (the protocol)
MCP = Model Context Protocol. It's a standard way for an AI agent to call real tools (APIs). Instead of hardcoding API calls into a prompt, the agent discovers and calls tools dynamically via MCP.

2. How a tool gets registered (the config layer)
mcp_servers/mcp_configs/ — each JSON file = one MCP server. It points to an OpenAPI spec and says "expose these API endpoints as agent tools."

3. How the API is described (the OpenAPI layer)
mcp_servers/openapi_specs/ — standard OpenAPI JSON files. The MCP platform reads these to know what parameters each tool takes and what it returns.

4. How it deploys to production (the infra layer)
Python scripts → validate config → upload spec to S3 → write config to DynamoDB → Jenkins pipeline across Dev → Galaxy → Staging → Production (US + EU).

5. How tools render UI (the frontend layer)
apps/mcp-ui-flare/ — React app that renders tool results as visual blocks inside a sandboxed iframe using JMESPath to map JSON responses to UI components.

"""
"""

Learning plan (we code in your notebook)
#	Topic	What you'll build
1	MCP basics — protocol, tools, resources	Call a mock MCP server
2	OpenAPI → MCP tool mapping	Write an OpenAPI spec, map it to a tool
3	Read a real config from this repo	Parse aquila_learning.json, understand every field
4	Build your own MCP server	Python MCP server with 2-3 tools
5	JMESPath for UI blocks	Transform JSON responses into UI data
6	Deployment flow	Understand the Jenkins pipeline end to end
Want to start Module 1 right now in your notebook? I'll write the first cells with explanation + runnable code.

"""
# Out:
# '\n1. What is MCP? (the protocol)\nMCP = Model Context Protocol. It\'s a standard way for an AI agent to call real tools (APIs). Instead of hardcoding API calls into a prompt, the agent discovers and calls tools dynamically via MCP.\n\n2. How a tool gets registered (the config layer)\nmcp_servers/mcp_configs/ — each JSON file = one MCP server. It points to an OpenAPI spec and says "expose these API endpoints as agent tools."\n\n3. How the API is described (the OpenAPI layer)\nmcp_servers/openapi_specs/ — standard OpenAPI JSON files. The MCP platform reads these to know what parameters each tool takes and what it returns.\n\n4. How it deploys to production (the infra layer)\nPython scripts → validate config → upload spec to S3 → write config to DynamoDB → Jenkins pipeline across Dev → Galaxy → Staging → Production (US + EU).\n\n5. How tools render UI (the frontend layer)\napps/mcp-ui-flare/ — React app that renders tool results as visual blocks inside a sandboxed iframe using JMESPath
# ...
